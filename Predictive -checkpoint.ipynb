# %% [markdown]
# # STARTUP SUCCESS PREDICTION

# %% [markdown]
#  ## BUSINESS UNDERSTANDING

# %% [markdown]
# A start-up is a company or project begun by an entrepreneur to seek, develop, and validate a scalable economic model. The goal is to forecast the outcome of startups that are currently in operation, determining whether they will achieve success or face failure. Success is defined as when a company's founders realize substantial financial gains through either a Merger and Acquisition (M&A) deal or an Initial Public Offering (IPO). Conversely, a company is deemed to have failed if it ends up shutting down.

# %% [markdown]
# ## LIBRARIES USED

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## DOWNLOADING DATASET

# %%
df=pd.read_csv(r"C:\Users\sahid\Desktop\startup_data.csv")

# %%
#checking the first 10 records
df.head(10)
# Out:
#    Unnamed: 0 state_code   latitude   longitude zip_code       id  \
# 0        1005         CA  42.358880  -71.056820    92101   c:6669
# 1         204         CA  37.238916 -121.973718    95032  c:16283
# 2        1001         CA  32.901049 -117.192656    92121  c:65620
# 3         738         CA  37.320309 -122.050040    95014  c:42668
# 4        1002         CA  37.779281 -122.419236    94105  c:65806
# 5         379         CA  37.406914 -122.090370    94043  c:22898
# 6         195         CA  37.391559 -122.070264    94041  c:16191
# 7         875         CA  38.057107 -122.513742    94901   c:5192
# 8          16         MA  42.712207  -73.203599     1267   c:1043
# 9         846         CA  37.427235 -122.145783    94306    c:498
#
#             city              Unnamed: 6                   name  labels  ...  \
# 0      San Diego                     NaN            Bandsintown       1  ...
# 1      Los Gatos                     NaN              TriCipher       1  ...
# ...

# %%
#checking the last 10 records
df.tail(10)
# Out:
#      Unnamed: 0 state_code   latitude   longitude zip_code       id  \
# 913         157         TX  29.739322  -95.444747    77027  c:15509
# 914         879         NY  40.750519  -73.993494    10001  c:52378
# 915         228         WI  43.090756  -89.522805    53562    c:167
# 916         284         NY  40.742953  -73.984461    10018  c:17758
# 917        1099         WA  47.802184 -122.196307    98021   c:8339
# 918         352         CA  37.740594 -122.376471    94107  c:21343
# 919         721         MA  42.504817  -71.195611     1803  c:41747
# 920         557         CA  37.408261 -122.015920    94089  c:31549
# 921         589         CA  37.556732 -122.288378    94404  c:33198
# 922         462         CA  37.386778 -121.966277    95054  c:26702
#
#               city            Unnamed: 6                  name  labels  ...  \
# 913        Houston                   NaN                Rudder       0  ...
# ...

# %%
#checking some random records
df.sample(10)
# Out:
#      Unnamed: 0 state_code   latitude   longitude zip_code        id  \
# 166         725         CA  37.758229 -122.439512    94114     c:421
# 520          11         NY  40.730646  -73.986614    10010  c:102867
# 328        1034         CA  37.779624 -122.391236    94107     c:725
# 713         900         TX  30.409765  -97.751010    78759   c:54488
# 546         373         CA  34.141199 -118.704091    91302   c:22712
# 211         291         CA  37.795191 -122.430411    94115    c:1789
# 466         482         CA  37.775206 -122.419209    94107   c:27591
# 521         741         CA  37.391642 -122.093935    94040     c:431
# 109         316         CT  41.853615  -72.703750     6002   c:19101
# 15          898         VA  38.901301  -77.265158    22182   c:54177
#
#               city              Unnamed: 6                             name  \
# 166  San Francisco                     NaN                    Crowd Factory
# ...

# %% [markdown]
# # DATA UNDERSTANDING
# ## Exploratory Data Anaysis and Visualization

# %%
# Checking the datatype of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923 entries, 0 to 922
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                923 non-null    int64
#  1   state_code                923 non-null    object
#  2   latitude                  923 non-null    float64
#  3   longitude                 923 non-null    float64
#  4   zip_code                  923 non-null    object
#  5   id                        923 non-null    object
#  6   city                      923 non-null    object
#  7   Unnamed: 6                430 non-null    object
#  8   name                      923 non-null    object
#  9   labels                    923 non-null    int64
#  10  founded_at                923 non-null    object
#  11  closed_at                 335 non-null    object
#  12  first_funding_at          923 non-null    object
# ...

# %% [markdown]
# ## Elimination of Columns

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 df.drop('Unnamed: 0',axis=1,inplace=True)
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %% [markdown]
# Upon inspection, it was discovered that the '**Unnamed: 0'** column contains arbitrary numbers, and the column name itself lacks a meaningful interpretation. Consequently, this column has been removed from the DataFrame.

# %%
df.drop('Unnamed: 6',axis=1,inplace=True)
df
# Out:
#     state_code   latitude   longitude zip_code           city  \
# 0           CA  42.358880  -71.056820    92101      San Diego
# 1           CA  37.238916 -121.973718    95032      Los Gatos
# 2           CA  32.901049 -117.192656    92121      San Diego
# 3           CA  37.320309 -122.050040    95014      Cupertino
# 4           CA  37.779281 -122.419236    94105  San Francisco
# ..         ...        ...         ...      ...            ...
# 918         CA  37.740594 -122.376471    94107  San Francisco
# 919         MA  42.504817  -71.195611     1803     Burlington
# 920         CA  37.408261 -122.015920    94089      Sunnyvale
# 921         CA  37.556732 -122.288378    94404  San Francisco
# 922         CA  37.386778 -121.966277    95054    Santa Clara
#
#                      name founded_at  closed_at first_funding_at  \
# 0             Bandsintown 2007-01-01        NaT         4/1/2009
# 1               TriCipher 2000-01-01        NaT        2/14/2005
# ...

# %% [markdown]
# The **'Unnamed: 6'** column is essentially a combination of the 'city', 'state_code', and 'zip_code' columns, so it has been eliminated from the DataFrame.

# %%
df.drop(['latitude','longitude'], axis=1,inplace=True)

# %% [markdown]
# We will use the company's address information, which includes the 'city,' 'state_code,' and 'zip_code,' for location details. As a result, we have decided to remove the 'latitude' and 'longitude' columns, as they are no longer needed.

# %%
#df['id'].nunique()
df
# Out:
#     state_code   latitude   longitude zip_code           city  \
# 0           CA  42.358880  -71.056820    92101      San Diego
# 1           CA  37.238916 -121.973718    95032      Los Gatos
# 2           CA  32.901049 -117.192656    92121      San Diego
# 3           CA  37.320309 -122.050040    95014      Cupertino
# 4           CA  37.779281 -122.419236    94105  San Francisco
# ..         ...        ...         ...      ...            ...
# 918         CA  37.740594 -122.376471    94107  San Francisco
# 919         MA  42.504817  -71.195611     1803     Burlington
# 920         CA  37.408261 -122.015920    94089      Sunnyvale
# 921         CA  37.556732 -122.288378    94404  San Francisco
# 922         CA  37.386778 -121.966277    95054    Santa Clara
#
#                      name founded_at  closed_at first_funding_at  \
# 0             Bandsintown 2007-01-01        NaT         4/1/2009
# 1               TriCipher 2000-01-01        NaT        2/14/2005
# ...

# %% [markdown]
# The 'id' column contains unique identifiers for each row (e.g., a unique ID or a primary key), it may not provide meaningful information for our analysis. Hence, we dropped the column.

# %%
#to compare two columns whether they contain same data
comparison = df['state_code'] == df['state_code.1']
mismatched_rows = df[~comparison]
mismatched_rows

# %% [markdown]
# There is only one discrepancy, which appears to be a typing error. Both the 'state_code' and 'state_code.1' columns contain identical values. As a result, we can safely remove the **'state_code.1'** column.

# %%
df.drop('state_code.1',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 df.drop('state_code.1',axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
df['status'] = df['status'].replace({'closed': 0, 'acquired': 1})
df['status'] = df['status'].astype(int)

# %% [markdown]
# We performed the following value transformations in the 'status' column:
# - Change 'acquired' to 1
# - Change 'closed' to 0
#
# This adjustment will make it easier to work with and analyze the 'status' column in our dataset. After converting we can compare
# columns 'labels' ansd 'status'.

# %%
#compare 'status' and 'labels'
#comparison = df['status'] == df['labels']
#mismatched_rows = df[~comparison]
mismatched_rows
# Out:
#      Unnamed: 0 state_code   latitude   longitude zip_code     id        city  \
# 515        1110         CA  37.451124 -122.166264    94025  c:856  Menlo Park
#
#     Unnamed: 6  name  labels  ... object_id has_VC has_angel has_roundA  \
# 515        NaN  Cuil       0  ...     c:856      0         0          1
#
#      has_roundB  has_roundC  has_roundD  avg_participants  is_top500  status
# 515           1           0           0               2.5          1       0
#
# [1 rows x 49 columns]

# %% [markdown]
# Since the values in both columns are identical, we have removed the 'labels' column.

# %%
df.drop('labels',axis=1,inplace=True)

# %%
df.columns

# %%
df['category_code'].unique()
# Out:
# array(['music', 'enterprise', 'web', 'software', 'games_video',
#        'network_hosting', 'finance', 'mobile', 'education',
#        'public_relations', 'security', 'other', 'photo_video', 'hardware',
#        'ecommerce', 'advertising', 'travel', 'fashion', 'analytics',
#        'consulting', 'cleantech', 'search', 'semiconductor', 'social',
#        'biotech', 'medical', 'automotive', 'messaging', 'manufacturing',
#        'hospitality', 'news', 'transportation', 'sports', 'real_estate',
#        'health'], dtype=object)

# %%
df.duplicated(keep=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 918    False
# 919    False
# 920    False
# 921    False
# 922    False
# Length: 838, dtype: bool

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     state_code   latitude   longitude zip_code           city  \
# 0           CA  42.358880  -71.056820    92101      San Diego
# 1           CA  37.238916 -121.973718    95032      Los Gatos
# 2           CA  32.901049 -117.192656    92121      San Diego
# 3           CA  37.320309 -122.050040    95014      Cupertino
# 4           CA  37.779281 -122.419236    94105  San Francisco
# ..         ...        ...         ...      ...            ...
# 918         CA  37.740594 -122.376471    94107  San Francisco
# 919         MA  42.504817  -71.195611     1803     Burlington
# 920         CA  37.408261 -122.015920    94089      Sunnyvale
# 921         CA  37.556732 -122.288378    94404  San Francisco
# 922         CA  37.386778 -121.966277    95054    Santa Clara
#
#                      name founded_at  closed_at first_funding_at  \
# 0             Bandsintown 2007-01-01        NaT         4/1/2009
# 1               TriCipher 2000-01-01        NaT        2/14/2005
# ...

# %%
#to view full dataframe
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
#to disable
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')

# %%
#to compare to columns whether they contain 
comparison = df['state_code'] == df['state_code.1']
mismatched_rows = df[~comparison]
mismatched_rows
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'state_code.1'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df['city'].value_counts()
# Out:
# San Francisco      114
# New York            81
# Mountain View       41
# Palo Alto           32
# Santa Clara         26
#                   ...
# The Woodlands        1
# Duluth               1
# North Billerica      1
# Bethesda             1
# Middleton            1
# Name: city, Length: 210, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     state_code   latitude   longitude zip_code           city  \
# 0           CA  42.358880  -71.056820    92101      San Diego
# 1           CA  37.238916 -121.973718    95032      Los Gatos
# 2           CA  32.901049 -117.192656    92121      San Diego
# 3           CA  37.320309 -122.050040    95014      Cupertino
# 4           CA  37.779281 -122.419236    94105  San Francisco
# ..         ...        ...         ...      ...            ...
# 918         CA  37.740594 -122.376471    94107  San Francisco
# 919         MA  42.504817  -71.195611     1803     Burlington
# 920         CA  37.408261 -122.015920    94089      Sunnyvale
# 921         CA  37.556732 -122.288378    94404  San Francisco
# 922         CA  37.386778 -121.966277    95054    Santa Clara
#
#                      name founded_at  closed_at first_funding_at  \
# 0             Bandsintown 2007-01-01        NaT         4/1/2009
# 1               TriCipher 2000-01-01        NaT        2/14/2005
# ...

# %%
df.columns
# Out:
# Index(['state_code', 'latitude', 'longitude', 'zip_code', 'city', 'name',
#        'founded_at', 'closed_at', 'first_funding_at', 'last_funding_at',
#        'age_first_funding_year', 'age_last_funding_year',
#        'age_first_milestone_year', 'age_last_milestone_year', 'relationships',
#        'funding_rounds', 'funding_total_usd', 'milestones', 'is_CA', 'is_NY',
#        'is_MA', 'is_TX', 'is_otherstate', 'category_code', 'is_software',
#        'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
#        'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting',
#        'is_othercategory', 'has_VC', 'has_angel', 'has_roundA', 'has_roundB',
#        'has_roundC', 'has_roundD', 'avg_participants', 'is_top500', 'status',
#        'last_date', 'age'],
#       dtype='object')

# %% [markdown]
# Dropping useless columns

# %%
df=df.drop(['state_code.1','Unnamed: 0','id','Unnamed: 6','object_id'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df=df.drop(['state_code.1','Unnamed: 0','id','Unnamed: 6','object_id'],axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %%
df['age_first_funding_year'].min()

# %% [markdown]
# Check for null

# %%
df.isnull().sum()
# Out:
# state_code                    0
# latitude                      0
# longitude                     0
# zip_code                      0
# city                          0
# name                          0
# founded_at                    0
# closed_at                   544
# first_funding_at              0
# last_funding_at               0
# age_first_funding_year        0
# age_last_funding_year         0
# age_first_milestone_year    143
# age_last_milestone_year     143
# relationships                 0
# funding_rounds                0
# funding_total_usd             0
# milestones                    0
# is_CA                         0
# is_NY                         0
# is_MA                         0
# is_TX                         0
# is_otherstate                 0
# category_code                 0
# is_software                   0
# is_web                        0
# is_mobile                     0
# is_enterprise                 0
# is_advertising                0
# ...

# %% [markdown]
# we will handle null in columns age_first_milestone_year and age_last_milestone_year.

# %%
df['age_first_milestone_year'].fillna(0)
df['age_last_milestone_year'].fillna(0)
# Out:
# 0      6.7041
# 1      7.0055
# 2      2.2055
# 3      6.0027
# 4      0.0384
#         ...
# 918    4.5260
# 919    6.0027
# 920    9.0055
# 921    3.8356
# 922    4.0027
# Name: age_last_milestone_year, Length: 838, dtype: float64

# %%
df.isnull().sum()
# Out:
# state_code                    0
# latitude                      0
# longitude                     0
# zip_code                      0
# city                          0
# name                          0
# founded_at                    0
# closed_at                   544
# first_funding_at              0
# last_funding_at               0
# age_first_funding_year        0
# age_last_funding_year         0
# age_first_milestone_year    143
# age_last_milestone_year     143
# relationships                 0
# funding_rounds                0
# funding_total_usd             0
# milestones                    0
# is_CA                         0
# is_NY                         0
# is_MA                         0
# is_TX                         0
# is_otherstate                 0
# category_code                 0
# is_software                   0
# is_web                        0
# is_mobile                     0
# is_enterprise                 0
# is_advertising                0
# ...

# %% [markdown]
# Convert the column status into binary.

# %%
df['status']=df['status'].replace({'acquired':1,'closed':0})

# %%
df['status'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    0
# Name: status, dtype: int32

# %% [markdown]
# compare the columns status and labels

# %%
compare= df['status']==df['labels']
compare.sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'labels'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# So we can see status and labels contains same value. so drop labels

# %%
df=df.drop('labels', axis=1)

# %%
df
# Out:
#     state_code   latitude   longitude zip_code           city  \
# 0           CA  42.358880  -71.056820    92101      San Diego
# 1           CA  37.238916 -121.973718    95032      Los Gatos
# 2           CA  32.901049 -117.192656    92121      San Diego
# 3           CA  37.320309 -122.050040    95014      Cupertino
# 4           CA  37.779281 -122.419236    94105  San Francisco
# ..         ...        ...         ...      ...            ...
# 918         CA  37.740594 -122.376471    94107  San Francisco
# 919         MA  42.504817  -71.195611     1803     Burlington
# 920         CA  37.408261 -122.015920    94089      Sunnyvale
# 921         CA  37.556732 -122.288378    94404  San Francisco
# 922         CA  37.386778 -121.966277    95054    Santa Clara
#
#                      name founded_at  closed_at first_funding_at  \
# 0             Bandsintown 2007-01-01        NaT         4/1/2009
# 1               TriCipher 2000-01-01        NaT        2/14/2005
# ...

# %% [markdown]
# Handling nan in 'closed_at' column

# %%
#change date into Pandas DateTime objects
df['closed_at']=pd.to_datetime(df['closed_at'])
df['founded_at']=pd.to_datetime(df['founded_at'])

# %%
#create a temporary column 'last_date' and fill all the null values with '2013-12-31' as the latest date available in the dataframe is '2013-12-31' 
df['last_date']=df['closed_at']
df['last_date']=df['last_date'].fillna('2013-12-31')
df['last_date']=pd.to_datetime(df['last_date'])

# %%
#calculate age 
df['age']= df['last_date']-df['founded_at']

# %%
df['age_last_funding_year'].max()
# Out:
# 21.8959

# %%
#rounded to integer value
df['age']=round(df.age/np.timedelta64(1,'Y'))

# %%
#checking for negative age in dataframe
df[['founded_at','closed_at','age_first_funding_year','age_last_funding_year', 'age_first_milestone_year','age_last_milestone_year','age']].sort_values("age")
# Out:
#     founded_at  closed_at  age_first_funding_year  age_last_funding_year  \
# 690 2012-08-01 2013-01-01                  0.0000                 0.6904
# 585 2012-01-01 2013-05-01                  0.2986                 0.2986
# 758 2010-10-04 2012-01-01                  0.8521                 0.8521
# 754 2011-03-01 2012-01-01                  0.1288                 0.2740
# 304 2010-01-01 2010-10-01                  0.8027                 0.8027
# ..         ...        ...                     ...                    ...
# 824 1996-01-01 2012-07-08                 11.1452                11.1452
# 505 1990-04-10 2010-01-01                 16.9863                16.9863
# 264 1992-01-01 2011-11-12                 16.4192                16.4192
# 100 1985-01-01 2009-05-03                 20.8055                20.8055
# 675 1984-01-01 2012-05-21                 21.8959                21.8959
#
#      age_first_milestone_year  age_last_milestone_year   age
# ...

# %%
#Age cannot be negative so dropping rows with negative age
df=df.drop(df[df.age_first_funding_year<0].index)
df=df.drop(df[df.age_last_funding_year<0].index)
df=df.drop(df[df.age_first_milestone_year<0].index)
df=df.drop(df[df.age_first_milestone_year<0].index)
df=df.drop(df[df.age<0].index)

# %%
df[['founded_at','closed_at','age_first_funding_year','age_last_funding_year', 'age_first_milestone_year','age_last_milestone_year','age']].sort_values("age")
# Out:
#     founded_at  closed_at  age_first_funding_year  age_last_funding_year  \
# 690 2012-08-01 2013-01-01                  0.0000                 0.6904
# 585 2012-01-01 2013-05-01                  0.2986                 0.2986
# 758 2010-10-04 2012-01-01                  0.8521                 0.8521
# 754 2011-03-01 2012-01-01                  0.1288                 0.2740
# 304 2010-01-01 2010-10-01                  0.8027                 0.8027
# ..         ...        ...                     ...                    ...
# 824 1996-01-01 2012-07-08                 11.1452                11.1452
# 505 1990-04-10 2010-01-01                 16.9863                16.9863
# 264 1992-01-01 2011-11-12                 16.4192                16.4192
# 100 1985-01-01 2009-05-03                 20.8055                20.8055
# 675 1984-01-01 2012-05-21                 21.8959                21.8959
#
#      age_first_milestone_year  age_last_milestone_year   age
# ...

# %%
df.isna().sum()
# Out:
# state_code                    0
# latitude                      0
# longitude                     0
# zip_code                      0
# city                          0
# name                          0
# founded_at                    0
# closed_at                   544
# first_funding_at              0
# last_funding_at               0
# age_first_funding_year        0
# age_last_funding_year         0
# age_first_milestone_year    143
# age_last_milestone_year     143
# relationships                 0
# funding_rounds                0
# funding_total_usd             0
# milestones                    0
# is_CA                         0
# is_NY                         0
# is_MA                         0
# is_TX                         0
# is_otherstate                 0
# category_code                 0
# is_software                   0
# is_web                        0
# is_mobile                     0
# is_enterprise                 0
# is_advertising                0
# ...

# %%
#handling null values in 'closed_at'
df['closed_at'].fillna('', inplace=True)

# %%
df.isnull().sum()
# Out:
# state_code                    0
# latitude                      0
# longitude                     0
# zip_code                      0
# city                          0
# name                          0
# founded_at                    0
# closed_at                   544
# first_funding_at              0
# last_funding_at               0
# age_first_funding_year        0
# age_last_funding_year         0
# age_first_milestone_year    143
# age_last_milestone_year     143
# relationships                 0
# funding_rounds                0
# funding_total_usd             0
# milestones                    0
# is_CA                         0
# is_NY                         0
# is_MA                         0
# is_TX                         0
# is_otherstate                 0
# category_code                 0
# is_software                   0
# is_web                        0
# is_mobile                     0
# is_enterprise                 0
# is_advertising                0
# ...

# %%
df['status'].value_counts()
# Out:
# 1    551
# 0    287
# Name: status, dtype: int64

# %%
df.dtypes
# Out:
# state_code                          object
# latitude                           float64
# longitude                          float64
# zip_code                            object
# city                                object
# name                                object
# founded_at                  datetime64[ns]
# closed_at                   datetime64[ns]
# first_funding_at                    object
# last_funding_at                     object
# age_first_funding_year             float64
# age_last_funding_year              float64
# age_first_milestone_year           float64
# age_last_milestone_year            float64
# relationships                        int64
# funding_rounds                       int64
# funding_total_usd                    int64
# milestones                           int64
# is_CA                                int64
# is_NY                                int64
# is_MA                                int64
# is_TX                                int64
# ...
